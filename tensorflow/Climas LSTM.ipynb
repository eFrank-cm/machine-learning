# %% [markdown]
# # Importing Needed Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.layers import Dense, LSTM, Dropout

from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Reading The Data

# %%
data_dir = '../dataset/DailyDelhiClimateTrain.csv'
df = pd.read_csv(data_dir)

# %% [markdown]
# # Data Exploration

# %%
df.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
df.tail()
# Out:
#             date   meantemp    humidity  wind_speed  meanpressure
# 1457  2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 1458  2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 1459  2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 1460  2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 1461  2017-01-01  10.000000  100.000000    0.000000   1016.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1462 entries, 0 to 1461
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1462 non-null   object
#  1   meantemp      1462 non-null   float64
#  2   humidity      1462 non-null   float64
#  3   wind_speed    1462 non-null   float64
#  4   meanpressure  1462 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 57.2+ KB

# %%
df.describe()
# Out:
#           meantemp     humidity   wind_speed  meanpressure
# count  1462.000000  1462.000000  1462.000000   1462.000000
# mean     25.495521    60.771702     6.802209   1011.104548
# std       7.348103    16.769652     4.561602    180.231668
# min       6.000000    13.428571     0.000000     -3.041667
# 25%      18.857143    50.375000     3.475000   1001.580357
# 50%      27.714286    62.625000     6.221667   1008.563492
# 75%      31.305804    72.218750     9.238235   1014.944901
# max      38.714286   100.000000    42.220000   7679.333333

# %% [markdown]
# ### Set Date column as an index

# %%
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace= True)

# %%
plt.figure(figsize=(15, 6))
df['meantemp'].plot()
plt.ylabel(None)
plt.xlabel(None)
plt.title("Mean Temperature")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))
df['humidity'].plot()
plt.ylabel(None)
plt.xlabel(None)
plt.title("Humidity")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))
df['wind_speed'].plot()
plt.ylabel(None)
plt.xlabel(None)
plt.title("Wind Spead")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))
df['meanpressure'].plot()
plt.ylabel(None)
plt.xlabel(None)
plt.title("Mean Pressure")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Choosing Prediction Column

# %%
n_cols = 1
dataset = df["meantemp"]
dataset = pd.DataFrame(dataset)
data = dataset.values

data.shape
# Out:
# (1462, 1)

# %% [markdown]
# ### Normalizing Data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range= (0, 1))
scaled_data = scaler.fit_transform(np.array(data))

# %% [markdown]
# ### Splitting Data

# %%
train_size = int(len(data) * 0.75)
test_size = len(data) - train_size
print("Train Size :",train_size,"Test Size :",test_size)
# Out:
# Train Size : 1096 Test Size : 366

# %%
train_data = scaled_data[0:train_size, :]
train_data.shape
# Out:
# (1096, 1)

# %% [markdown]
# ### Creating training set

# %%
# Creating a Training set with 60 time-steps
x_train = []
y_train = []
time_steps = 60
n_cols = 1

for i in range(time_steps, len(scaled_data)):
    x_train.append(scaled_data[i-time_steps:i, :n_cols])
    y_train.append(scaled_data[i, :n_cols])
    if i<=time_steps:
        print('X_train: ', x_train)
        print('y_train:' , y_train)
# Out:
# X_train:  [array([[0.12227074],
#        [0.04279476],
#        [0.0356623 ],
#        [0.08151383],
#        [0.        ],
#        [0.03056769],
#        [0.03056769],
#        [0.08733624],
#        [0.24454148],
#        [0.15283843],
#        [0.29694323],
#        [0.24454148],
#        [0.30058224],
#        [0.20887918],
#        [0.26637555],
#        [0.23944687],
#        [0.3209607 ],
#        [0.23944687],
#        [0.19868996],
#        [0.16157205],
#        [0.15895197],
#        [0.1069869 ],
#        [0.24454148],
#        [0.23944687],
#        [0.19104803],
#        [0.20378457],
#        [0.20960699],
#        [0.27001456],
#        [0.24836245],
#        [0.26637555],
#        [0.31179039],
#        [0.30567686],
#        [0.31441048],
#        [0.36681223],
#        [0.34934498],
#        [0.32478166],
#        [0.32605531],
#        [0.29344978],
#        [0.24454148],
#        [0.28820961],
#        [0.28275109],
#        [0.3018559 ],
#        [0.2852984 ],
#        [0.31441048],
#        [0.34643377],
#        [0.40247453],
#        [0.25764192],
#        [0.23435226],
#        [0.29344978],
#        [0.30131004],
#        [0.3580786 ],
#        [0.4279476 ],
#        [0.44323144],
#        [0.34934498],
#        [0.33187773],
#        [0.33242358],
#        [0.36244541],
#        [0.45240175],
#        [0.41048035],
#        [0.34643377]])]
# y_train: [array([0.39737991])]

# %%
# Convert to numpy array
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
# Reshaping the input to (n_samples, time_steps, n_feature)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], n_cols))

# %%
x_train.shape , y_train.shape
# Out:
# ((1402, 60, 1), (1402, 1))

# %% [markdown]
# # LSTM Model

# %% [markdown]
# ### Model Structure

# %%
model = Sequential([
    LSTM(50, return_sequences= True, input_shape= (x_train.shape[1], n_cols)),
    LSTM(64, return_sequences= False),
    Dense(32),
    Dense(16),
    Dense(n_cols)
])

model.compile(optimizer= 'adam', loss= 'mse' , metrics= "mean_absolute_error")

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 50)            10400
#
#  lstm_1 (LSTM)               (None, 64)                29440
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 42,465
# Trainable params: 42,465
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model Training

# %%
# Fitting the LSTM to the Training set
history = model.fit(x_train, y_train, epochs= 100, batch_size= 32)
# Out:
# Epoch 1/100
# 44/44 [==============================] - 6s 20ms/step - loss: 0.0314 - mean_absolute_error: 0.1234
# Epoch 2/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0058 - mean_absolute_error: 0.0606
# Epoch 3/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0052 - mean_absolute_error: 0.0574
# Epoch 4/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0051 - mean_absolute_error: 0.0560
# Epoch 5/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0048 - mean_absolute_error: 0.0540
# Epoch 6/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0047 - mean_absolute_error: 0.0538
# Epoch 7/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0048 - mean_absolute_error: 0.0543
# Epoch 8/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0046 - mean_absolute_error: 0.0533
# Epoch 9/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0050 - mean_absolute_error: 0.0553
# Epoch 10/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0044 - mean_absolute_error: 0.0519
# Epoch 11/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0045 - mean_absolute_error: 0.0523
# Epoch 12/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0044 - mean_absolute_error: 0.0521
# Epoch 13/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0044 - mean_absolute_error: 0.0522
# Epoch 14/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0043 - mean_absolute_error: 0.0519
# Epoch 15/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0042 - mean_absolute_error: 0.0501
# Epoch 16/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0040 - mean_absolute_error: 0.0494
# Epoch 17/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0039 - mean_absolute_error: 0.0490
# Epoch 18/100
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0037 - mean_absolute_error: 0.0476
# Epoch 19/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0037 - mean_absolute_error: 0.0474
# Epoch 20/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0035 - mean_absolute_error: 0.0460
# Epoch 21/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0035 - mean_absolute_error: 0.0465
# Epoch 22/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0033 - mean_absolute_error: 0.0447
# Epoch 23/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0033 - mean_absolute_error: 0.0443
# Epoch 24/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0032 - mean_absolute_error: 0.0444
# Epoch 25/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0030 - mean_absolute_error: 0.0423
# Epoch 26/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0036 - mean_absolute_error: 0.0473
# Epoch 27/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0032 - mean_absolute_error: 0.0445
# Epoch 28/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0027 - mean_absolute_error: 0.0403
# Epoch 29/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0027 - mean_absolute_error: 0.0404
# Epoch 30/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0032 - mean_absolute_error: 0.0437
# Epoch 31/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0029 - mean_absolute_error: 0.0418
# Epoch 32/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0026 - mean_absolute_error: 0.0385
# Epoch 33/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0025 - mean_absolute_error: 0.0388
# Epoch 34/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0029 - mean_absolute_error: 0.0418
# Epoch 35/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0026 - mean_absolute_error: 0.0391
# Epoch 36/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0026 - mean_absolute_error: 0.0394
# Epoch 37/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0025 - mean_absolute_error: 0.0384
# Epoch 38/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0025 - mean_absolute_error: 0.0380
# Epoch 39/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0026 - mean_absolute_error: 0.0390
# Epoch 40/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0025 - mean_absolute_error: 0.0380
# Epoch 41/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0025 - mean_absolute_error: 0.0381
# Epoch 42/100
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0025 - mean_absolute_error: 0.0379
# Epoch 43/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0026 - mean_absolute_error: 0.0390
# Epoch 44/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0025 - mean_absolute_error: 0.0385
# Epoch 45/100
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0026 - mean_absolute_error: 0.0392
# Epoch 46/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0027 - mean_absolute_error: 0.0399
# Epoch 47/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0024 - mean_absolute_error: 0.0375
# Epoch 48/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0024 - mean_absolute_error: 0.0377
# Epoch 49/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0026 - mean_absolute_error: 0.0393
# Epoch 50/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0025 - mean_absolute_error: 0.0383
# Epoch 51/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0026 - mean_absolute_error: 0.0387
# Epoch 52/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0026 - mean_absolute_error: 0.0388
# Epoch 53/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0024 - mean_absolute_error: 0.0371
# Epoch 54/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0024 - mean_absolute_error: 0.0378
# Epoch 55/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0024 - mean_absolute_error: 0.0376
# Epoch 56/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0026 - mean_absolute_error: 0.0388
# Epoch 57/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0024 - mean_absolute_error: 0.0374
# Epoch 58/100
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0024 - mean_absolute_error: 0.0373
# Epoch 59/100
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0025 - mean_absolute_error: 0.0379
# Epoch 60/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0025 - mean_absolute_error: 0.0376
# Epoch 61/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0030 - mean_absolute_error: 0.0425
# Epoch 62/100
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0026 - mean_absolute_error: 0.0391
# Epoch 63/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0025 - mean_absolute_error: 0.0385
# Epoch 64/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0026 - mean_absolute_error: 0.0393
# Epoch 65/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0025 - mean_absolute_error: 0.0376
# Epoch 66/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0024 - mean_absolute_error: 0.0369
# Epoch 67/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0025 - mean_absolute_error: 0.0383
# Epoch 68/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0024 - mean_absolute_error: 0.0377
# Epoch 69/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0026 - mean_absolute_error: 0.0380
# Epoch 70/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0025 - mean_absolute_error: 0.0381
# Epoch 71/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0024 - mean_absolute_error: 0.0381
# Epoch 72/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0024 - mean_absolute_error: 0.0369
# Epoch 73/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0024 - mean_absolute_error: 0.0373
# Epoch 74/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0024 - mean_absolute_error: 0.0372
# Epoch 75/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0023 - mean_absolute_error: 0.0368
# Epoch 76/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0025 - mean_absolute_error: 0.0380
# Epoch 77/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0024 - mean_absolute_error: 0.0374
# Epoch 78/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0025 - mean_absolute_error: 0.0381
# Epoch 79/100
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0024 - mean_absolute_error: 0.0375
# Epoch 80/100
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0025 - mean_absolute_error: 0.0386
# Epoch 81/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0024 - mean_absolute_error: 0.0372
# Epoch 82/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0024 - mean_absolute_error: 0.0371
# Epoch 83/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0024 - mean_absolute_error: 0.0370
# Epoch 84/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0025 - mean_absolute_error: 0.0384
# Epoch 85/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0027 - mean_absolute_error: 0.0395
# Epoch 86/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0026 - mean_absolute_error: 0.0389
# Epoch 87/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0025 - mean_absolute_error: 0.0378
# Epoch 88/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0025 - mean_absolute_error: 0.0379
# Epoch 89/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0025 - mean_absolute_error: 0.0379
# Epoch 90/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0025 - mean_absolute_error: 0.0381
# Epoch 91/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0024 - mean_absolute_error: 0.0379
# Epoch 92/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0024 - mean_absolute_error: 0.0373
# Epoch 93/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0024 - mean_absolute_error: 0.0366
# Epoch 94/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0025 - mean_absolute_error: 0.0384
# Epoch 95/100
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0025 - mean_absolute_error: 0.0381
# Epoch 96/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0024 - mean_absolute_error: 0.0371
# Epoch 97/100
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0025 - mean_absolute_error: 0.0380
# Epoch 98/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0027 - mean_absolute_error: 0.0400
# Epoch 99/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0024 - mean_absolute_error: 0.0370
# Epoch 100/100
# 44/44 [==============================] - 1s 18ms/step - loss: 0.0025 - mean_absolute_error: 0.0386

# %% [markdown]
# ### Model Evaluation

# %%
plt.figure(figsize=(12, 8))
plt.plot(history.history["loss"])
plt.plot(history.history["mean_absolute_error"])
plt.legend(['Mean Squared Error','Mean Absolute Error'])
plt.title("Losses")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# # Predection

# %% [markdown]
# ### Creating testing set

# %%
# Creating a testing set with 60 time-steps and 1 output
time_steps = 60
test_data = scaled_data[train_size - time_steps:, :]

x_test = []
y_test = []
n_cols = 1

for i in range(time_steps, len(test_data)):
    x_test.append(test_data[i-time_steps:i, 0:n_cols])
    y_test.append(test_data[i, 0:n_cols])
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], n_cols))

# %%
# Get Prediction
predictions = model.predict(x_test)
# Out:
# 12/12 [==============================] - 1s 14ms/step

# %%
predictions.shape
# Out:
# (366, 1)

# %%
#inverse predictions scaling
predictions = scaler.inverse_transform(predictions)
predictions.shape
# Out:
# (366, 1)

# %% [markdown]
# ### Root mean square error

# %%
#inverse y_test scaling
y_test = scaler.inverse_transform(y_test)

# %%
RMSE = np.sqrt(np.mean( y_test - predictions )**2).round(2)
RMSE
# Out:
# 0.12

# %%
preds_acts = pd.DataFrame(data={'Predictions':predictions.flatten(), 'Actuals':y_test.flatten()})
preds_acts
# Out:
#      Predictions    Actuals
# 0      14.887319  14.000000
# 1      14.390093  14.375000
# 2      14.483314  15.750000
# 3      15.405025  15.833333
# 4      15.749730  17.375000
# ..           ...        ...
# 361    17.010544  17.217391
# 362    17.253551  15.238095
# 363    16.011459  14.095238
# 364    14.894123  15.052632
# 365    15.181990  10.000000
#
# [366 rows x 2 columns]

# %%
plt.figure(figsize = (16, 6))
plt.plot(preds_acts['Predictions'])
plt.plot(preds_acts['Actuals'])
plt.legend(['Predictions', 'Actuals'])
plt.show()

# %% [markdown]
# ### Visualize Predictions with The Data
# for one feature

# %%
train = dataset.iloc[:train_size , 0:1]
test = dataset.iloc[train_size: , 0:1]
test['Predictions'] = predictions

plt.figure(figsize= (16, 6))
plt.title('Temperature Prediction', fontsize= 18)
plt.xlabel('Date', fontsize= 18)
plt.ylabel('Temperature', fontsize= 18)
plt.plot(train['meantemp'], linewidth= 3)
plt.plot(test['meantemp'], linewidth= 3)
plt.plot(test["Predictions"], linewidth= 3)
plt.legend(['Train', 'Test', 'Predictions'])

# %% [markdown]
# # Multivariate Predection

# %%
df.head()
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %% [markdown]
# ### Chose Columns

# %%
n_cols = 4
# date	meantemp	humidity	wind_speed	meanpressure
cols = list(df.loc[:, ['meantemp', 'humidity', 'wind_speed', 'meanpressure']])
dataset = df[cols]
dataset = pd.DataFrame(dataset)
data = dataset.values

data.shape
# Out:
# (1462, 4)

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Data Normalization

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range= (0, 1))
scaled_data = scaler.fit_transform(np.array(data))

# %% [markdown]
# ### Data Splitting

# %%
train_size = int(len(data) * 0.75)
test_size = len(data) - train_size
print("Train Size :",train_size,"Test Size :",test_size)
# Out:
# Train Size : 1096 Test Size : 366

# %%
train_data = scaled_data[0:train_size, :]
train_data.shape
# Out:
# (1096, 4)

# %% [markdown]
# ### Creating Train Data

# %%
# Creating a Training set with 60 time-steps
x_train = []
y_train = []
time_steps = 60
n_cols = 4

for i in range(time_steps, len(train_data)):
    x_train.append(train_data[i-time_steps:i, :n_cols])
    y_train.append(train_data[i, :n_cols])
    if i<=time_steps:
        print('X_train: ', x_train)
        print('y_train:' , y_train)
# Out:
# X_train:  [array([[0.12227074, 0.8209571 , 0.        , 0.13260331],
#        [0.04279476, 0.90759076, 0.07058266, 0.132881  ],
#        [0.0356623 , 0.84983498, 0.10974262, 0.13299381],
#        [0.08151383, 0.66886689, 0.02921206, 0.13279856],
#        [0.        , 0.84790979, 0.08763619, 0.13271178],
#        [0.03056769, 0.80132013, 0.03505448, 0.13290703],
#        [0.03056769, 0.75280528, 0.14921838, 0.13316737],
#        [0.08733624, 0.58085809, 0.16918184, 0.13300001],
#        [0.24454148, 0.43688119, 0.29606821, 0.13277686],
#        [0.15283843, 0.56105611, 0.17527238, 0.13260331],
#        [0.29694323, 0.43729373, 0.25038912, 0.13266529],
#        [0.24454148, 0.69966997, 0.31332476, 0.13259091],
#        [0.30058224, 0.71314631, 0.10974262, 0.13229958],
#        [0.20887918, 0.86331133, 0.01460603, 0.13253822],
#        [0.26637555, 0.67491749, 0.01251946, 0.1326281 ],
#        [0.23944687, 0.8459846 , 0.        , 0.13273348],
#        [0.3209607 , 0.77860286, 0.12434865, 0.132625  ],
#        [0.23944687, 0.90951595, 0.21198484, 0.13245144],
#        [0.19868996, 0.73047305, 0.13934944, 0.13338432],
#        [0.16157205, 0.71452145, 0.20064966, 0.13320456],
#        [0.15895197, 0.73432343, 0.05258171, 0.13329754],
#        [0.1069869 , 0.76512651, 0.07303016, 0.13340167],
#        [0.24454148, 0.53987899, 0.09513659, 0.13323245],
#        [0.23944687, 0.54565457, 0.14606032, 0.13323245],
#        [0.19104803, 0.61881188, 0.13145429, 0.133265  ],
#        [0.20378457, 0.58608361, 0.16106111, 0.13312398],
#        [0.20960699, 0.60231023, 0.13162347, 0.13292563],
#        [0.27001456, 0.49174917, 0.08763619, 0.13288534],
#        [0.24836245, 0.60148515, 0.07668167, 0.13272805],
#        [0.26637555, 0.65841584, 0.02503891, 0.13288844],
#        [0.31179039, 0.60264026, 0.07010895, 0.1329591 ],
#        [0.30567686, 0.68811881, 0.05258171, 0.1326467 ],
#        [0.31441048, 0.74092409, 0.03146782, 0.13279546],
#        [0.36681223, 0.60231023, 0.04398728, 0.13255372],
#        [0.34934498, 0.7029703 , 0.26324694, 0.13246074],
#        [0.32478166, 0.91192244, 0.23034107, 0.13269551],
#        [0.32605531, 0.66886689, 0.20448445, 0.13299381],
#        [0.29344978, 0.5310231 , 0.25438181, 0.13298513],
#        [0.24454148, 0.65841584, 0.21925966, 0.13279546],
#        [0.28820961, 0.55280528, 0.21925966, 0.13275827],
#        [0.28275109, 0.67079208, 0.08230696, 0.13279314],
#        [0.3018559 , 0.65924092, 0.12612506, 0.13271178],
#        [0.2852984 , 0.65731573, 0.17566714, 0.13284195],
#        [0.31441048, 0.65511551, 0.14414292, 0.1326467 ],
#        [0.34643377, 0.58223322, 0.10263698, 0.13240806],
#        [0.40247453, 0.59955996, 0.24119691, 0.13208264],
#        [0.25764192, 0.91584158, 0.20098802, 0.13160535],
#        [0.23435226, 0.88448845, 0.        , 0.1322128 ],
#        [0.29344978, 0.75049505, 0.28943629, 0.13267273],
#        [0.30131004, 0.79207921, 0.13771402, 0.13260951],
#        [0.3580786 , 0.70792079, 0.13771402, 0.13277686],
#        [0.4279476 , 0.62211221, 0.15666238, 0.13257231],
#        [0.44323144, 0.60292904, 0.25757935, 0.1326467 ],
#        [0.34934498, 0.70957096, 0.21925966, 0.13277686],
#        [0.33187773, 0.75577558, 0.17527238, 0.13301861],
#        [0.33242358, 0.68667492, 0.10984131, 0.13293957],
#        [0.36244541, 0.65346535, 0.41656798, 0.13253512],
#        [0.45240175, 0.50561056, 0.15774514, 0.13254256],
#        [0.41048035, 0.45544554, 0.30689585, 0.13283265],
#        [0.34643377, 0.41474147, 0.57003   , 0.13269009]])]
# y_train: [array([0.39737991, 0.46864686, 0.37245381, 0.13267924])]

# %%
# Convert to numpy array
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
# Reshaping the input to (n_samples, time_steps, n_feature)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], n_cols))
x_train.shape , y_train.shape
# Out:
# ((1036, 60, 4), (1036, 4))

# %% [markdown]
# ## Model Structure

# %%
model2 = Sequential([
    LSTM(50, return_sequences= True, input_shape= (x_train.shape[1], n_cols)),
    LSTM(64, return_sequences= False),
    Dense(32),
    Dense(16),
    Dense(n_cols)
])

model2.compile(optimizer= 'adam', loss= 'mse' , metrics= "mean_absolute_error")

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 60, 50)            11000
#
#  lstm_3 (LSTM)               (None, 64)                29440
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 16)                528
#
#  dense_5 (Dense)             (None, 4)                 68
#
# =================================================================
# Total params: 43,116
# Trainable params: 43,116
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model Training

# %%
# Fitting the LSTM to the Training set
history2 = model2.fit(x_train, y_train, epochs= 100, batch_size= 32)
# Out:
# Epoch 1/100
# 33/33 [==============================] - 4s 21ms/step - loss: 0.0342 - mean_absolute_error: 0.1238
# Epoch 2/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0090 - mean_absolute_error: 0.0659
# Epoch 3/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0086 - mean_absolute_error: 0.0643
# Epoch 4/100
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0083 - mean_absolute_error: 0.0629
# Epoch 5/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0082 - mean_absolute_error: 0.0615
# Epoch 6/100
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0077 - mean_absolute_error: 0.0604
# Epoch 7/100
# 33/33 [==============================] - 1s 21ms/step - loss: 0.0076 - mean_absolute_error: 0.0582
# Epoch 8/100
# 33/33 [==============================] - 1s 22ms/step - loss: 0.0076 - mean_absolute_error: 0.0589
# Epoch 9/100
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0074 - mean_absolute_error: 0.0583
# Epoch 10/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0074 - mean_absolute_error: 0.0583
# Epoch 11/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0071 - mean_absolute_error: 0.0558
# Epoch 12/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0070 - mean_absolute_error: 0.0556
# Epoch 13/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0071 - mean_absolute_error: 0.0577
# Epoch 14/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0071 - mean_absolute_error: 0.0565
# Epoch 15/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0071 - mean_absolute_error: 0.0584
# Epoch 16/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0068 - mean_absolute_error: 0.0556
# Epoch 17/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0067 - mean_absolute_error: 0.0548
# Epoch 18/100
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0070 - mean_absolute_error: 0.0572
# Epoch 19/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0064 - mean_absolute_error: 0.0533
# Epoch 20/100
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0064 - mean_absolute_error: 0.0534
# Epoch 21/100
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0063 - mean_absolute_error: 0.0516
# Epoch 22/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0062 - mean_absolute_error: 0.0523
# Epoch 23/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0062 - mean_absolute_error: 0.0522
# Epoch 24/100
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0064 - mean_absolute_error: 0.0527
# Epoch 25/100
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0060 - mean_absolute_error: 0.0508
# Epoch 26/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0060 - mean_absolute_error: 0.0512
# Epoch 27/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0060 - mean_absolute_error: 0.0506
# Epoch 28/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0059 - mean_absolute_error: 0.0499
# Epoch 29/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0061 - mean_absolute_error: 0.0511
# Epoch 30/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0060 - mean_absolute_error: 0.0513
# Epoch 31/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0059 - mean_absolute_error: 0.0509
# Epoch 32/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0058 - mean_absolute_error: 0.0492
# Epoch 33/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0057 - mean_absolute_error: 0.0484
# Epoch 34/100
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0057 - mean_absolute_error: 0.0493
# Epoch 35/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0062 - mean_absolute_error: 0.0520
# Epoch 36/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0057 - mean_absolute_error: 0.0492
# Epoch 37/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0057 - mean_absolute_error: 0.0494
# Epoch 38/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0056 - mean_absolute_error: 0.0482
# Epoch 39/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0057 - mean_absolute_error: 0.0493
# Epoch 40/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0059 - mean_absolute_error: 0.0503
# Epoch 41/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0056 - mean_absolute_error: 0.0494
# Epoch 42/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0057 - mean_absolute_error: 0.0487
# Epoch 43/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0054 - mean_absolute_error: 0.0476
# Epoch 44/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0058 - mean_absolute_error: 0.0494
# Epoch 45/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0055 - mean_absolute_error: 0.0479
# Epoch 46/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0056 - mean_absolute_error: 0.0479
# Epoch 47/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0055 - mean_absolute_error: 0.0476
# Epoch 48/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0054 - mean_absolute_error: 0.0469
# Epoch 49/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0056 - mean_absolute_error: 0.0488
# Epoch 50/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0056 - mean_absolute_error: 0.0485
# Epoch 51/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0054 - mean_absolute_error: 0.0475
# Epoch 52/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0054 - mean_absolute_error: 0.0465
# Epoch 53/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0054 - mean_absolute_error: 0.0470
# Epoch 54/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0054 - mean_absolute_error: 0.0467
# Epoch 55/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0055 - mean_absolute_error: 0.0479
# Epoch 56/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0054 - mean_absolute_error: 0.0479
# Epoch 57/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0054 - mean_absolute_error: 0.0466
# Epoch 58/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0054 - mean_absolute_error: 0.0467
# Epoch 59/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0055 - mean_absolute_error: 0.0473
# Epoch 60/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0056 - mean_absolute_error: 0.0483
# Epoch 61/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0054 - mean_absolute_error: 0.0475
# Epoch 62/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0054 - mean_absolute_error: 0.0475
# Epoch 63/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0054 - mean_absolute_error: 0.0472
# Epoch 64/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0054 - mean_absolute_error: 0.0477
# Epoch 65/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0053 - mean_absolute_error: 0.0462
# Epoch 66/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0053 - mean_absolute_error: 0.0472
# Epoch 67/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0056 - mean_absolute_error: 0.0480
# Epoch 68/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0052 - mean_absolute_error: 0.0462
# Epoch 69/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0053 - mean_absolute_error: 0.0458
# Epoch 70/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0054 - mean_absolute_error: 0.0481
# Epoch 71/100
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0053 - mean_absolute_error: 0.0465
# Epoch 72/100
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0053 - mean_absolute_error: 0.0465
# Epoch 73/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0054 - mean_absolute_error: 0.0472
# Epoch 74/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0054 - mean_absolute_error: 0.0469
# Epoch 75/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0052 - mean_absolute_error: 0.0466
# Epoch 76/100
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0052 - mean_absolute_error: 0.0453
# Epoch 77/100
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0053 - mean_absolute_error: 0.0461
# Epoch 78/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0051 - mean_absolute_error: 0.0452
# Epoch 79/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0053 - mean_absolute_error: 0.0457
# Epoch 80/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0053 - mean_absolute_error: 0.0469
# Epoch 81/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0052 - mean_absolute_error: 0.0456
# Epoch 82/100
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0051 - mean_absolute_error: 0.0453
# Epoch 83/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0051 - mean_absolute_error: 0.0449
# Epoch 84/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0051 - mean_absolute_error: 0.0449
# Epoch 85/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0051 - mean_absolute_error: 0.0447
# Epoch 86/100
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0052 - mean_absolute_error: 0.0453
# Epoch 87/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0051 - mean_absolute_error: 0.0452
# Epoch 88/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0051 - mean_absolute_error: 0.0453
# Epoch 89/100
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0052 - mean_absolute_error: 0.0465
# Epoch 90/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0052 - mean_absolute_error: 0.0460
# Epoch 91/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0051 - mean_absolute_error: 0.0450
# Epoch 92/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0051 - mean_absolute_error: 0.0452
# Epoch 93/100
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0053 - mean_absolute_error: 0.0461
# Epoch 94/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0051 - mean_absolute_error: 0.0452
# Epoch 95/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0050 - mean_absolute_error: 0.0444
# Epoch 96/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0049 - mean_absolute_error: 0.0435
# Epoch 97/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0050 - mean_absolute_error: 0.0441
# Epoch 98/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0050 - mean_absolute_error: 0.0443
# Epoch 99/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0050 - mean_absolute_error: 0.0443
# Epoch 100/100
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0050 - mean_absolute_error: 0.0445

# %% [markdown]
# ### Model Evaluation

# %%
plt.figure(figsize=(12, 8))
plt.plot(history2.history["loss"])
plt.plot(history2.history["mean_absolute_error"])
plt.legend(['Mean Squared Error','Mean Absolute Error'])
plt.title("Losses")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# ## Prediction

# %% [markdown]
# ### Creating Test Data

# %%
# Creating a testing set with 60 time-steps and 1 output
time_steps = 60
test_data = scaled_data[train_size - time_steps:, :]

x_test = []
y_test = []
n_cols = 4

for i in range(time_steps, len(test_data)):
    x_test.append(test_data[i-time_steps:i, 0:n_cols])
    y_test.append(test_data[i, 0:n_cols])
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], n_cols))

# %%
x_test.shape , y_test.shape
# Out:
# ((366, 60, 4), (366, 4))

# %%
# Get Prediction
predictions = model2.predict(x_test)
# Out:
# 12/12 [==============================] - 1s 15ms/step

# %%
#inverse y_test scaling
y_test = scaler.inverse_transform(y_test)

# %%
RMSE = np.sqrt(np.mean( y_test - predictions )**2).round(2)
RMSE
# Out:
# 277.78
